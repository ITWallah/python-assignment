# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
=> Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy.
->Histograms
->scatter plot
->bar chart
->line
->step

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
## answer 2:

import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as pyt

# %%
pyt.scatter(x,y)
pyt.title("Title of diagram")
pyt.xlabel("My X axis")
pyt.ylabel("My Y axis")
# Out:
# Text(0, 0.5, 'My Y axis')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
## answer 3:

import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
The subplot() function is used in data visualization libraries, such as Matplotlib, to create multiple plots within a single figure. 
It allows you to divide the figure into a grid of subplots and specify which subplot to draw on.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# Line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# Line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# Line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a figure with a 2x2 grid of subplots
plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title('Line 4')

plt.tight_layout()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
## answer 4:

import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
pyt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
pyt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
## answer 5:

A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties
like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile
to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data
to be plotted while the y-axis shows the frequency distribution.

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
pyt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6e20451ba0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6e204520e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6e20451900>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6e20452620>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6e204528c0>],
#  'means': []}

# %%
pyt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6e204b4670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6e204b4bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6e204b43d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6e204b4fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6e204b5270>],
#  'means': []}
